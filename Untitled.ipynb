# %% [markdown]
# Importing

# %%
import numpy as np
import pandas as pd
import keras 
import cv2 
import matplotlib.pyplot as plt
import os
import random
from PIL import Image
import tensorflow as tf

# %%
df = pd.read_csv('train.csv')
base_path = "./images"

# %%
df
# Out:
#                        id  landmark_id
# 0        17660ef415d37059            1
# 1        92b6290d571448f6            1
# 2        cd41bf948edc0340            1
# 3        fb09f1e98c6d2f70            1
# 4        25c9dfc7ea69838d            7
# ...                   ...          ...
# 1580465  72c3b1c367e3d559       203092
# 1580466  7a6a2d9ea92684a6       203092
# 1580467  9401fad4c497e1f9       203092
# 1580468  aacc960c9a228b5f       203092
# 1580469  d9e338c530dca106       203092
#
# [1580470 rows x 2 columns]

# %%
samples = 20000

#df =  df.iloc[ : samples, :  ]  # start from 0 to 20000 with non steps
df = df.loc[df['id'].str.startswith('00',na=False),:]
num_classes = len(df["landmark_id"].unique())
num_data = len(df)

# %%
num_classes
# Out:
# 5346

# %%
num_data
# Out:
# 6120

# %%
data = pd.DataFrame(df['landmark_id'].value_counts())
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#    landmark_id  count
# 0       138982     31
# 1        83144     14
# 2       194914      7
# 3       126637      7
# 4         9673      6

# %%
data.tail()
# Out:
#       landmark_id  count
# 5341       202886      1
# 5342       202939      1
# 5343       202950      1
# 5344       202972      1
# 5345       202981      1

# %%
data.columns=['landmark_id','count']

# %%
data['count'].describe()
# Out:
# count    5346.000000
# mean        1.144781
# std         0.641260
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max        31.000000
# Name: count, dtype: float64

# %%
plt.hist(data['count'],100, range=(0,31), label = "test")
# Out:
# (array([0.000e+00, 0.000e+00, 0.000e+00, 4.781e+03, 0.000e+00, 0.000e+00,
#         4.520e+02, 0.000e+00, 0.000e+00, 7.500e+01, 0.000e+00, 0.000e+00,
#         2.200e+01, 0.000e+00, 0.000e+00, 0.000e+00, 9.000e+00, 0.000e+00,
#         0.000e+00, 3.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
data['count'].between(0,5).sum()
# Out:
# np.int64(5339)

# %%
plt.hist(df['landmark_id'], bins=sorted(df['landmark_id'].unique()))
# Out:
# (array([2., 1., 1., ..., 1., 1., 2.]),
#  array([2.70000e+01, 6.00000e+01, 1.24000e+02, ..., 2.02950e+05,
#         2.02972e+05, 2.02981e+05]),
#  <BarContainer object of 5345 artists>)

# %% [markdown]
# Training of Model

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

encoder.fit(df['landmark_id'])
# Out:
# LabelEncoder()

# %%
df.head()
# Out:
#                     id  landmark_id
# 119   00cba0067c078490           27
# 120   00f928e383e1d121           27
# 796   009ecdb56b5e9adb           60
# 1089  00d5d47528839144          124
# 1133  00e9003a381ab809          134

# %% [markdown]
# Encoding

# %%
def  encode_label(lbl):
    return encoder.transform(lbl)

# %% [markdown]
# Decoding

# %%
def decode_label(lbl):
    return encoder.inverse_transform(lbl)

# %%
def get_image_from_number(num,df):
    fname, label = df.iloc[num, :]
    fname = fname + '.jpg'
    f1 = fname[0]
    f2 = fname[1]
    f3 = fname[2]
    path = os.path.join(base_path,f1,f2,f3,fname)
    im = cv2.imread(path)
    return im,label

# %%
print("4 Samples images from random classes")
fig = plt.figure(figsize=(16,16))
for i in range(1,5):
    ri = random.choices(os.listdir(base_path), k=3)
    folder = base_path + '/' + ri[0] + '/'+ ri[1]+'/'+ri[2]
    random_img = random.choice(os.listdir(folder))
    img = np.array(Image.open(folder+'/'+random_img))
    fig.add_subplot(1,4,i)
    plt.imshow(img)
    plt.axis('off')
plt.show()
# Out:
# 4 Samples images from random classes

# %% [markdown]
# Build the Model

# %%
from keras.applications.vgg19 import VGG19
from keras.layers import *   # Everything
from keras import Sequential
tf.compat.v1.disable_eager_execution()
# Out:
# WARNING:tensorflow:From C:\Users\hisha\AppData\Local\Temp\ipykernel_9436\3313601475.py:4: The name tf.disable_eager_execution is deprecated. Please use tf.compat.v1.disable_eager_execution instead.

# %%
learing_rat     = 0.0001
decay_sped      = 1e-6
momemtu         = 0.09
loss_fucntion   = 'sparse_categorical_crossentropy'
source_entropy  = VGG19(weights=None)
drop_layer = Dropout(0.5)
drop_layer = Dropout(0.5)

# %% [markdown]
# Model

# %%
model = Sequential()
for layer in source_entropy.layers[:-1]:
    if layer == source_entropy.layers[-25]:
        model.add(BatchNormalization())
    model.add(layer)
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization             │ (None, 224, 224, 3)    │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from tensorflow.keras.optimizers import RMSprop

optim1 = RMSprop(
    learning_rate=learing_rat,
    decay=decay_sped,
    momentum=momemtu
)
model.compile(optimizer=optim1,
              loss=loss_fucntion,
              metrics=["accuracy"]
              )
# Out:
# c:\Users\hisha\Desktop\New\ISTOP\Main project\myenv\Lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
def image_reshape(im, target_size):
    return cv2.resize(im, target_size)

# %%
def get_batch(dataFrame, start, batch_size):
    image_array = []
    label_array = []
    
    end_img = start + batch_size
    if (end_img) > len(dataFrame):
        end_img = len(dataFrame)
        
    for idx in range(start, end_img):
        n =idx
        im, label = get_image_from_number(n,dataFrame)
        im = image_reshape(im, (224,224)) / 255.0
        image_array.append(im)
        label_array.append(label)
        
    label_array = encode_label(label_array)
    
    return np.array(image_array) , np.array(label_array)

# %% [markdown]
# Split

# %%
train, val = np.split(df.sample(frac=1),[int(0.8*len(df))])
print(len(train))
print(len(val))
# Out:
# 4896
# 1224
# c:\Users\hisha\Desktop\New\ISTOP\Main project\myenv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
batch_size = 16
epoch_shuffle = True
weight_classes = True
epochs = 1

# %%
for e in range(epochs):
    print("Epoch : "+ str(e+1) + "/"+ str(epochs))
    if epoch_shuffle:
        train = train.sample(frac=1)
    for it in range(int(np.ceil(len(train)/batch_size))):
        X_train, y_train = get_batch(train, it*batch_size, batch_size)
        
        model.train_on_batch(X_train, y_train)
        
model.save("model.h5")

# %%
batch_size = 16

errors = 0
good_pred = []
bad_pred = []

for it in range(int(np.ceil(len(val)/batch_size))):
    X_val, y_val = get_batch(val, it*batch_size, batch_size)
    
    result = model.predict(X_val)
    cla = np.argmax(result, axis=1)
    for idx, res in enumerate(result):
        if cla[idx] != y_val[idx] :
            errors = errors + 1
            bad_pred.append([batch_size * it + idx, cla[idx], res[cla[idx]]])
        else:
            good_pred.append([batch_size * it + idx,cla[idx],res[cla[idx]]])
# Out:
# c:\Users\hisha\Desktop\New\ISTOP\Main project\myenv\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[89], line 10
#       7 for it in range(int(np.ceil(len(val)/batch_size))):
#       8     X_val, y_val = get_batch(val, it*batch_size, batch_size)
# ---> 10     result = model.predict(X_val)
#      11     cla = np.argmax(result, axis=1)
#      12     for idx, res in enumerate(result):
#
# ...

# %%
good_pred = np.array(good_pred)
good_pred = np.array(sorted(good_pred, key=lambda x: x[2], reverse=True))

# %%
len(good_pred)
# Out:
# 0

# %%
fig = plt.figure(figsize=(16,16))
for i in range(len(good_pred)):
    n = int(good_pred[i][0])
    img, lbl = get_image_from_number(n,val)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    fig.add_subplot(1, len(good_pred), i+1)
    plt.imshow(img)
    lbl2 = np.array(int(good_pred[i,1])).reshape(1,1)
    sample_cnt = list(df.landmark_id).count(lbl)   
    plt.title(
        f"Label : {lbl}\n"
        f"\nClassified as: {decode_label(lbl2)}\n"
        f"\nSample in class {lbl} : {sample_cnt}"
        
    )
    
    plt.axis('off')
    
plt.show()
